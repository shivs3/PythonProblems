# %%
import requests
import json
from pprint import pprint

# %%
accesskey = "Mnpj4xET2fK1s56Q0HpOSEUUXnspxiQUjdioa2gL4OQ756dAMb"
def newsApi(find=None, sortby=None, find_title=None,fromdate=None,todate=None):
    url = 'https://fcsapi.com/api-v2/news/news?'

    querystring = {
        "access_key":accesskey,
        "find": find,
        "find_title": find_title,
        "sortby": sortby,
        "from":fromdate,
        "to":todate

    }
    payload = ""
    headers = {
        'content-type': "application/json"
    }

    response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
    res_data = json.loads(response.text)
    print(res_data)

# %%
newsApi(find='USD')
# Out:
# {'status': True, 'code': 200, 'msg': 'Successfully', 'response': [{'source': 'https://www.reuters.com/article/brief-saipem-wins-contract-in-brazil-of-idUSFWN2ED00B', 'author': 'Reuters Editorial', 'title': 'BRIEF-Saipem Wins Contract In Brazil Of About USD 325 Mln - Reuters', 'description': 'BRIEF-Saipem Wins Contract In Brazil Of About USD 325 Mln\xa0\xa0Reuters', 'publishedAt': '2020-07-06T05:38:00Z', 'content': 'July 6 (Reuters) - Saipem SpA: \r\n* AWARDED A CONTRACT FOR THE BÚZIOS PRE-SALT FIELD IN BRAZIL WORTH APPROXIMATELY 325 MILLION USD \r\n* CONTRACT BY PETROBRAS REGARDS INSTALLATION OF RIGID RISER-BASED S… [+136 chars]', 'image': 'https://s4.reutersmedia.net/resources_v2/images/rcom-default.png', 'site': 'Reuters'}, {'source': 'https://www.reuters.com/article/brief-vinacapital-vietnam-opportunity-fu-idUSFWN2EG126', 'author': 'Reuters Editorial', 'title': 'BRIEF-Vinacapital Vietnam Opportunity Fund Says June Unaudited, Estimated NAV Was $5 Per Share - Reuters', 'description'
# ...
